# %% [markdown]
# <H1>Automobiles - Model Development</H1>
#
# <h4>Raunak Singh</h4>
#
#
# Objectives –
# - To develop prediction models

# %% [markdown]
# <p>In this section, I will develop several models that will predict the price of the car using the variables or features. This is just an estimate but should give us an objective idea of how much the car should cost.</p>

# %% [markdown]
# Some questions we want to ask in this module
# <ul>
#     <li>Do I know if the dealer is offering fair value for my trade-in?</li>
#     <li>Do I know if I put a fair value on my car?</li>
# </ul>
# <p>In data analytics, we often use <b>Model Development</b> to help us predict future observations from the data we have.</p>
#
# <p>A model will help us understand the exact relationship between different variables and how these variables are used to predict the result.</p>

# %%
# import libraries: 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# Load the data into an object 'url':
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv"

# Mount the data onto a dataframe named 'df':
df = pd.read_csv(url, header = 0)
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %% [markdown]
# <h2>1. Linear Regression and Multiple Linear Regression</h2>

# %% [markdown]
# <h4>Simple Linear Regression</h4>
#
#
# <p>One example of a Data  Model that we will be using is:</p>
# <b>Simple Linear Regression</b>
#
# <br>
# <p>Simple Linear Regression is a method to help us understand the relationship between two variables:</p>
# <ul>
#     <li>The predictor/independent variable (X)</li>
#     <li>The response/dependent variable (that we want to predict)(Y)</li>
# </ul>
#
# <p>The result of Linear Regression is a <b>linear function</b> that predicts the response (dependent) variable as a function of the predictor (independent) variable.</p>
#
# $$
#  Y: Response \ Variable \\\\\\\
#  X: Predictor \ Variables
# $$
#
#
#  <b>Linear Function:</b>
# $$
# Yhat = a + b  X
# $$
#
# <ul>
#     <li><b>a</b> refers to the <b>intercept</b> of the regression line, in other words: the value of Y when X is 0</li>
#     <li><b>b</b> refers to the <b>slope</b> of the regression line, in other words: the value with which Y changes when X increases by 1 unit</li>
# </ul>

# %%
# Loading the modules for linear regression models: 
from sklearn.linear_model import LinearRegression

# Create the linear regression object: 
lm = LinearRegression()

# %% [markdown]
# <h4>How could "highway-mpg" help us predict car price?</h4>
#
# For this example, we want to look at how highway-mpg can help us predict car price.
# Using simple linear regression, we will create a linear function with "highway-mpg" as the predictor variable and the "price" as the response variable.

# %%
# Assign the values to the variables of interest: 
X = df[['highway-mpg']] # Predictor variable
Y = df['price'] # Target variable

# Fit the linear model using 'highway-mpg': 
lm.fit(X,Y)

# Output the prediction: 
Yhat = lm.predict(X)
print("Yhat =", Yhat[0:5])

# Value of intercept (a):
print("Intercept of the line (a) =", lm.intercept_)

# Value of the slobe (b):
print("Slope of the line (b) =", lm.coef_)

# Value of the Predictor Variable: 
print("Predictor Variable (X)", X)
# Out:
# Yhat = [16236.50464347 16236.50464347 17058.23802179 13771.3045085
#  20345.17153508]
# Intercept of the line (a) = 38423.305858157415
# Slope of the line (b) = [-821.73337832]
# Predictor Variable (X)      highway-mpg
# 0             27
# 1             27
# 2             26
# 3             30
# 4             22
# ..           ...
# 196           28
# 197           25
# 198           23
# 199           27
# 200           25
#
# [201 rows x 1 columns]

# %% [markdown]
# <H5>Based on the above calculations and outcomes, we can derive that:</H5>
#
# * a = 38423.305858157415
# * b = -821.73337832
# * X = df['highway-mpg']
#
# $$
# Yhat = a + b  X
# $$
#
# Substituting the values into the equation, it can be re-written as:
# <b>Price</b> = 38423.31 - 821.73 x <b>highway-mpg</b>

# %% [markdown]
# <h5>Create a Linear Regression model (<b>lm1</b>):</h5>
#
# - <b>Train the model using "engine-size" as the independent variable and "price" as the dependent variable?</b>
# - <b>Find the slope and intercept of the model.</b>

# %%
lm1 = LinearRegression()

# Assign the values to the variables of interest: 
X1 = df[['engine-size']] # Predictor variable
Y1 = df['price'] # Target variable

# Fit the linear model using 'engine-mpg':
lm1.fit(X1,Y1)

# Output the prediction: 
Yhat_1 = lm1.predict(X1)

# Print the outcome of the prediction: 
print("Yhat_1 =", Yhat_1[0:5])

# Print the intercept (a1):
print("Intercept of the line (a1) =", lm1.intercept_)

# Print the slope of the line (b1):
print("Slope of the line (b1) =", lm1.coef_)

# Value of the predictor variable (X1):
print("Predictor Variable (X1)", X1)
# Out:
# Yhat_1 = [13728.4631336  13728.4631336  17399.38347881 10224.40280408
#  14729.62322775]
# Intercept of the line (a1) = -7963.338906281046
# Slope of the line (b1) = [166.86001569]
# Predictor Variable (X1)      engine-size
# 0            130
# 1            130
# 2            152
# 3            109
# 4            136
# ..           ...
# 196          141
# 197          141
# 198          173
# 199          145
# 200          141
#
# [201 rows x 1 columns]

# %% [markdown]
# Equation of the Predicted Line (<b>Yhat_1</b>):
# $$
# Yhat = a + bX
# $$
#
# Price = -7963.33 + 166.86*<b>df['engine-size']</b>

# %% [markdown]
# <h4>Multiple Linear Regression</h4>
#
# <p>What if we want to predict car price using more than one variable?</p>
#
# <p>If we want to use more variables in our model to predict car price, we can use <b>Multiple Linear Regression</b>.
# Multiple Linear Regression is very similar to Simple Linear Regression, but this method is used to explain the relationship between one continuous response (dependent) variable and <b>two or more</b> predictor (independent) variables.
# Most of the real-world regression models involve multiple predictors. I will illustrate the structure by using four predictor variables, but these results can generalize to any integer:</p>
#
# $$
# Y: Response \ Variable\\\\\\\
# X_1 :Predictor\ Variable \ 1\\\
# X_2: Predictor\ Variable \ 2\\\
# X_3: Predictor\ Variable \ 3\\\
# X_4: Predictor\ Variable \ 4\\\
# $$
#
# $$
# a: intercept\\\\\\\
# b_1 :coefficients \ of\ Variable \ 1\\\
# b_2: coefficients \ of\ Variable \ 2\\\
# b_3: coefficients \ of\ Variable \ 3\\\
# b_4: coefficients \ of\ Variable \ 4\\\
# $$
#
#
# The equation, therefore, is given by:
# $$
# Yhat = a + b_1 X_1 + b_2 X_2 + b_3 X_3 + b_4 X_4
# $$

# %% [markdown]
# <p>From the previous section  we know that other good predictors of price could be:</p>
# <ul>
#     <li>Horsepower</li>
#     <li>Curb-weight</li>
#     <li>Engine-size</li>
#     <li>Highway-mpg</li>
# </ul>
# Let's develop a mutiple regression model using these variables as the predictor variables.

# %%
# Create an object Z that stores all the predictor variables of interest:
Z = df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]

# Fit the linear model using the four above-mentioned variables of interest: 
lm1.fit(Z, df['price'])

# Value of intercept (a):
print("Value of intercept (a1) =", lm1.intercept_)

# Value of coefficients (b1, b2, b3, b4) using the FOR-loop: 
n = 1
for out_coef in lm1.coef_:
    print("Value of coefficient", n , "for model #1 =" , out_coef)
    n = n+1
# Out:
# Value of intercept (a1) = -15806.624626329227
# Value of coefficient 1 for model #1 = 53.49574422604913
# Value of coefficient 2 for model #1 = 4.707700994613942
# Value of coefficient 3 for model #1 = 81.5302638212276
# Value of coefficient 4 for model #1 = 36.05748881648594

# %% [markdown]
# Final estimated model should fit in the following function:
# $$
# Yhat = a + b_1 X_1 + b_2 X_2 + b_3 X_3 + b_4 X_4
# $$
#
# So, the linear function in this example will serve as:
#
# <b>Price</b> = -15806.62 + 53.49 x <b>horsepower</b> + 4.70 x <b>curb-weight</b> + 81.53 x <b>engine-size</b> + 36.05 x <b>highway-mpg</b>

# %%
# Create a linear regression model lm2:
lm2 = LinearRegression()

# Create an object Z that stores all the predictor variables of interest:
Z_2 = df[['normalized-losses', 'highway-mpg']]

# Fit the linear model using the four above-mentioned variables of interest: 
lm2.fit(Z_2, df['price'])

# Value of intercept (a):
print("Value of intercept (a2) =", lm2.intercept_)

# Value of coefficients (b1, b2) using the FOR-loop: 
m = 0
for out_coef_2 in lm2.coef_:
    print("Value of the coefficient", m, "for model #2 =", out_coef_2)
    m = m+1
# Out:
# Value of intercept (a2) = 38201.31327245733
# Value of the coefficient 0 for model #2 = 1.4978958634132604
# Value of the coefficient 1 for model #2 = -820.4543401631879

# %% [markdown]
# <H3>2. Model Evaluation Using Visualisation</H3>
#
# I will now evaluate my models and choose the best one. One of the ways of doing that is employing visualisation.

# %%
# Import the modules needed for the process: 
import seaborn as sns 
# %matplotlib inline

# %% [markdown]
# <H4>Regression Plot</H4
#
# It is an excellent way to visualize the fit of our model is by using <b>regression plots</b>.</p>
#
# <p>This plot will show a combination of a scattered data points (a <b>scatterplot</b>), as well as the fitted <b>linear regression</b> line going through the data. This will give us a reasonable estimate of the relationship between the two variables, the strength of the correlation, as well as the direction (positive or negative correlation).</p>

# %%
# Visulaise highway-mpg as potential predictor variable of price: 
width = 12
height = 10
plt.figure(figsize = (width, height))
sns.regplot(x = "highway-mpg", y = 'price', data=df)
plt.ylim(0,)
# Out:
# (0.0, 48179.74831159791)

# %% [markdown]
# It is implied here that there is a strong negative correlation as depicted in the graph since it is negative slope.
#
# when looking at a regression plot is to pay attention to how scattered the data points are around the regression line. This will give us a good indication of the variance of the data and whether a linear model would be the best fit or not.
# * If the data is too far off from the line, this linear model might not be the best model for this data.

# %%
# Compare the 'peak-rpm' with 'price': 
plt.figure(figsize= (width, height))
sns.regplot(x = 'peak-rpm', y = 'price', data = df)
plt.ylim(0,)
# Out:
# (0.0, 47414.1)

# %% [markdown]
# <p>Comparing the regression plot of "peak-rpm" and "highway-mpg", we see that the points for "highway-mpg" are much closer to the generated line and, on average, decrease. The points for "peak-rpm" have more spread around the predicted line and it is much harder to determine if the points are decreasing or increasing as the "peak-rpm" increases.</p>

# %% [markdown]
# We shall now determine, based on the regression plots above, is 'peak-rpm' or 'highway-mpg' more strongly correlated with 'price'?
#
# I will use the `.corr()` method to determine the relationship.

# %%
df[['peak-rpm', 'highway-mpg', 'price']].corr()
# Out:
#              peak-rpm  highway-mpg     price
# peak-rpm     1.000000    -0.058598 -0.101616
# highway-mpg -0.058598     1.000000 -0.704692
# price       -0.101616    -0.704692  1.000000

# %% [markdown]
# The variable "highway-mpg" has a stronger correlation with "price", it is approximate -0.704692  compared to "peak-rpm" which is approximate -0.101616

# %% [markdown]
# <H4>Residual Plot</H4
#
# It is a good way to visualise the variance in the data.
#
# Definition of __Residual__: <p>The difference between the observed value (y) and the predicted value (Yhat) is called the residual (e). When we look at a regression plot, the residual is the distance from the data point to the fitted regression line.</p>
#
# <p>Definition of <b>residual plot</b>?</p>
#
# <p>A residual plot is a graph that shows the residuals on the vertical y-axis and the independent variable on the horizontal x-axis.</p>
#
# <p>What are the things to look out for in a residual plot?</p>
#
# <p>We look at the spread of the residuals:</p>
#
# - <p> If the points in a residual plot are <b>randomly spread out around the x-axis</b>, then a <b>linear model is appropriate</b> for the data.
#
# Why is that? Randomly spread out residuals means that the variance is constant, and thus the linear model is a good fit for this data.</p>

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.residplot(x = df['highway-mpg'], y = df['price'])
plt.show()

# %% [markdown]
# Inference:
#
# The residuals are not randomly spread around the x-axis (predictor/independent variable), which may indicate that we may be dealing with a non-linear model.

# %% [markdown]
# <h4>Multiple Linear Regression</h4>
#
# <p>How do we visualize a model for Multiple Linear Regression? This gets a bit more complicated because you can't visualize it with regression or residual plot.</p>
#
# <p>One way to look at the fit of the model is by looking at the <b>distribution plot</b>. We can look at the distribution of the fitted values that result from the model and compare it to the distribution of the actual values.</p>

# %%
# First step is to make a prediction: 
Y_hat = lm1.predict(Z)

# Second step is to depoy a *distribution plot*:
plt.figure(figsize = (width, height))

ax1 = sns.distplot(df['price'], hist = False, color = "r", label = "Actual Value")
sns.distplot(Y_hat, hist= False, color = "b", label = "Fitted Value", ax = ax1)

plt.title("Actual Value vs. Fitted Value for Price")
plt.xlabel("Price (in Dollars)")
plt.ylabel("Proportion of Cars")

plt.show()
plt.close()
# Out:
# /var/folders/49/x6ntbgk10bq51xzjz0y7zyqm0000gn/T/ipykernel_56649/774248328.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1 = sns.distplot(df['price'], hist = False, color = "r", label = "Actual Value")
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /var/folders/49/x6ntbgk10bq51xzjz0y7zyqm0000gn/T/ipykernel_56649/774248328.py:8: UserWarning:
#
# ...

# %% [markdown]
# <p>We can see that the fitted values are reasonably close to the actual values since the two distributions overlap a bit. However, there is definitely some room for improvement.</p>

# %% [markdown]
# <h3>3. Polynomial Regression and Pipelines</h3>
#
# <p><b>Polynomial regression</b> is a particular case of the general linear regression model or multiple linear regression models.</p>
# <p>We get non-linear relationships by squaring or setting higher-order terms of the predictor variables.</p>
#
# <p>There are different orders of polynomial regression:</p>
#
#
# <center><b>Quadratic - 2nd Order</b></center>
# $$
# Yhat = a + b_1 X +b_2 X^2
# $$
#
#
# <center><b>Cubic - 3rd Order</b></center>
# $$
# Yhat = a + b_1 X +b_2 X^2 +b_3 X^3\\\\\\
# $$
#
#
# <center><b>Higher-Order</b>:</center>
# $$
# Y = a + b_1 X +b_2 X^2 +b_3 X^3 ....\\
# $$

# %% [markdown]
# <p>We saw earlier that a linear model did not provide the best fit while using "highway-mpg" as the predictor variable. Let's see if we can try fitting a polynomial model to the data instead.</p>

# %%
# We will use the following function to plot the data: 
def PlotPolly(model, independent_variable, dependent_variable, name):
    x_new = np.linspace(15,55,100)
    y_new = model(x_new)

    plt.plot(independent_variable, dependent_variable, '.', x_new, y_new, '-')
    plt.title('Polynomial Fit with Matplotlib for Price ~ Length')
    ax = plt.gca()
    ax.set_facecolor((0.898, 0.898, 0.898))
    fig = plt.gcf()
    plt.xlabel(name)
    plt.ylabel("Price of Cars")

    plt.show()
    plt.close()

# Fetch the variables: 
x = df['highway-mpg']
y = df['price']

# Fit the polynomials using the function 'polyfit', and then 'poly1d' to display the polynomial function: 
# Here, I will use a polynomial of the 3rd order (cubic degree):
f = np.polyfit(x,y,3)
p = np.poly1d(f)
print(p)
# Out:
#         3         2
# -1.557 x + 204.8 x - 8965 x + 1.379e+05

# %%
# Plot the function: 
PlotPolly(p,x,y,'highway-mpg')

# %%
np.polyfit(x,y,3)
# Out:
# array([-1.55663829e+00,  2.04754306e+02, -8.96543312e+03,  1.37923594e+05])

# %% [markdown]
# <p>We can already see from plotting that this polynomial model performs better than the linear model. This is because the generated polynomial function  "hits" more of the data points.</p>

# %%
f11 = np.polyfit(x,y,11)
p11 = np.poly1d(f11)
print(p11)
PlotPolly(p11, x, y, 'Highway MPG')
# Out:
#             11             10             9           8         7
# -1.243e-08 x  + 4.722e-06 x  - 0.0008028 x + 0.08056 x - 5.297 x
#           6        5             4             3             2
#  + 239.5 x - 7588 x + 1.684e+05 x - 2.565e+06 x + 2.551e+07 x - 1.491e+08 x + 3.879e+08

# %% [markdown]
# <p>The analytical expression for Multivariate Polynomial function gets complicated. For example, the expression for a second-order (degree=2) polynomial with two variables is given by:</p>
#
# $$
# Yhat = a + b_1 X_1 +b_2 X_2 +b_3 X_1 X_2+b_4 X_1^2+b_5 X_2^2
# $$

# %%
# Perform a polynomial transform on multiple features.
# Import required modules: 
from sklearn.preprocessing import PolynomialFeatures

# Create a PolynomialFeature object of degree 2: 
pr = PolynomialFeatures(degree=2)
pr
# Out:
# PolynomialFeatures()

# %%
# Fit the model created:
Z_pr = pr.fit_transform(Z)

# In the original data, there are 201 samples and 4 features. 
Z.shape
# Out:
# (201, 4)

# %% [markdown]
# <H2>Pipeline</H2>
#
# <p>Data Pipelines simplify the steps of processing the data.
#
# - We use the module <b>Pipeline</b> to create a pipeline.
# - We also use <b>StandardScaler</b> as a step in our pipeline.</p>

# %%
# Import the necessary modules: 
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# Create the pipeline by creating a list of tuples including the name of the model or estimator and its corresponding constructor: 
Input = [('scale', StandardScaler()), ('polynomial', PolynomialFeatures(include_bias = False)), ('model', LinearRegression())]

# Input the list as an argument to the pipeline constructor: 
pipe = Pipeline(Input)
pipe
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynomial', PolynomialFeatures(include_bias=False)),
#                 ('model', LinearRegression())])

# %% [markdown]
# First, we convert the data type Z to type float to avoid conversion warnings that may appear as a result of StandardScaler taking float inputs.
#
# Then, we can normalize the data,  perform a transform and fit the model simultaneously.

# %%
Z = Z.astype('float')
pipe.fit(Z,y)
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynomial', PolynomialFeatures(include_bias=False)),
#                 ('model', LinearRegression())])

# %% [markdown]
# Similarly,  I will normalize the data, perform a transform and produce a prediction  simultaneously.

# %%
ypipe = pipe.predict(Z)
ypipe[0:5]
# Out:
# array([13102.74784201, 13102.74784201, 18225.54572197, 10390.29636555,
#        16136.29619164])

# %% [markdown]
# <H4>I will now create a pipeline that standardises the data, then produce a prediction using a linear regression model using the features Z and target y.</H4>

# %%
Input = [('scale', StandardScaler()), ("model", LinearRegression())]
pipe = Pipeline(Input)
pipe.fit(Z,y)
ypipe = pipe.predict(Z)
ypipe[0:10]
# Out:
# array([13699.11161184, 13699.11161184, 19051.65470233, 10620.36193015,
#        15521.31420211, 13869.66673213, 15456.16196732, 15974.00907672,
#        17612.35917161, 10722.32509097])

# %% [markdown]
# <H2>4. Measures For In-Sample Evaluation</H2>
#
# <p>When evaluating models, not only do we want to visualize the results, but we also want a quantitative measure to determine how accurate the model is.</p>
#
# <p>Two very important measures that are often used in Statistics to determine the accuracy of a model are:</p>
# <ul>
#     <li><b>R^2 / R-squared</b></li>
#     <li><b>Mean Squared Error (MSE)</b></li>
# </ul>
#
# <b>R-squared (R^2):</b>
#
# <p>R squared, also known as the coefficient of determination, is a measure to indicate how close the data is to the fitted regression line.</p>
#
# <p>The value of the R-squared is the percentage of variation of the response variable (y) that is explained by a linear model.</p>
#
#
#
# <b>Mean Squared Error (MSE):</b>
#
# <p>The Mean Squared Error measures the average of the squares of errors. That is, the difference between actual value (y) and the estimated value (ŷ).</p>

# %% [markdown]
# <H3>Model 1: Simple Linear Regression – </H3>

# %% [markdown]
# <h5>Calculate R-squared (R^2):-</h5>

# %%
# Calculate R^2:

# highway_mpg_fit
lm.fit(X,Y)

print("R-square (R^2) =", lm.score(X,Y))
# Out:
# R-square (R^2) = 0.4965911884339175

# %% [markdown]
# Inference: We can say that ~49.659% of the variation of the price is explained by this simple linear model "horsepower_fit".

# %% [markdown]
# <h5>Calculate Mean Squared Error (MSE):-</h5>

# %%
# Calculate MSE:

# We can predict the output i.e., 'yhat' using the `predict` method, where X is the input variable: 
Yhat = lm.predict(X)
print("The output of the first four predicted values =", Yhat[0:4])
# Out:
# The output of the first four predicted values = [16236.50464347 16236.50464347 17058.23802179 13771.3045085 ]

# %%
# Import the MSE function from the metrics module: 
from sklearn.metrics import mean_squared_error

# Compare the predicted results with the actual results: 
mse = mean_squared_error(df['price'], Yhat)
print("The mean square error (MSE) and predicted value =", mse)
# Out:
# The mean square error (MSE) and predicted value = 31635042.944639895

# %% [markdown]
# <H3>Model 2: Multiple Linear Regression – </H3>

# %% [markdown]
# <h5>Calculate R-squared (R^2):-</h5>

# %%
# Fit the model: 
lm.fit(Z, df['price'])

# Find the R^2:
print("The R-squared (R^2) =", lm.score(Z,df['price']))
# Out:
# The R-squared (R^2) = 0.8093562806577457

# %% [markdown]
# Inference: We can say that ~80.896 % of the variation of price is explained by this multiple linear regression "multi_fit".

# %% [markdown]
# <h5>Calculate Mean Squared Error (MSE):-</h5>

# %%
# Create a prediction model: 
Y_predict_multifit = lm.predict(Z)

# Compare teh predicted results with the actual results: 
print("The mean squared error of price and predicted value using multifit =", mean_squared_error(df['price'], Y_predict_multifit))
# Out:
# The mean squared error of price and predicted value using multifit = 11980366.87072649

# %% [markdown]
# <H3>Model 3: Polynomial Fit – </H3>

# %%
# Calculate R^2: 
# Import r2_score function from the module metrics as this will be a different function to be used: 
from sklearn.metrics import r2_score

# Apply the function to get the value of R^2: 
r_squared = r2_score(y, p(x))

# Print the result of the fit: 
print(("The R-square value =", r_squared))
# Out:
# ('The R-square value =', 0.674194666390652)

# %% [markdown]
# Inference: ~67.419 % of the variation of price is explained by this polynomial fit.

# %%
# Calculate MSE: 
mean_squared_error(df['price'], p(x))
# Out:
# 20474146.426361218

# %% [markdown]
# <h2>5. Predictions and Decision Making</h2>
#
# <H4>Prediction: </H4> <p>Previously, I have trained a model using the method <b>fit</b>. Now, I will use the method <b>predict</b> to make a prediction. </p>

# %%
# Import pyplot module for plotting: 
import matplotlib.pyplot as plt
import numpy as np 
# %matplotlib inline

# Create a new input: 
new_input = np.arange(1,100,1).reshape(-1,1)

# Fit the model: 
lm.fit(X,Y)
lm

# Produce a prediction: 
yhat = lm.predict(new_input)
yhat[0:5]
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([37601.57247984, 36779.83910151, 35958.10572319, 35136.37234487,
#        34314.63896655])

# %%
# Plot the data derived above: 
plt.plot(new_input, yhat)
plt.show()

# %% [markdown]
# <h3>Decision Making: Determining a Good Model Fit</h3>
#
# Now that we have visualised the different models, and generated the R-sqaured and MSE values for the fits, how do we determine a good model fit?
#
# * _What is a good __R-squared__ value?_
#   - The model with the `higher R-squared` value is a `better fit` for the data.
# * _What is a good __MSE__?_
#   - The model with the `smallest MSE` value is a `better fit` for the data.
#
# <h4>Let's take a look at the values for the different models.</h4>
# <p>Simple Linear Regression: Using Highway-mpg as a Predictor Variable of Price.
# <ul>
#     <li>R-squared: 0.49659118843391759</li>
#     <li>MSE: 3.16 x10^7</li>
# </ul>
# </p>
#
# <p>Multiple Linear Regression: Using Horsepower, Curb-weight, Engine-size, and Highway-mpg as Predictor Variables of Price.
# <ul>
#     <li>R-squared: 0.80896354913783497</li>
#     <li>MSE: 1.2 x10^7</li>
# </ul>
# </p>
#
# <p>Polynomial Fit: Using Highway-mpg as a Predictor Variable of Price.
# <ul>
#     <li>R-squared: 0.6741946663906514</li>
#     <li>MSE: 2.05 x 10^7</li>
# </ul>
# </p>

# %% [markdown]
# <h3>Simple Linear Regression Model (SLR) vs Multiple Linear Regression Model (MLR)</h3>
#
#
# <p>Usually, the more variables you have, the better your model is at predicting, but this is not always true. Sometimes you may not have enough data, you may run into numerical problems, or many of the variables may not be useful and even act as noise. As a result, you should always check the MSE and R^2.</p>
#
# <p>In order to compare the results of the MLR vs SLR models, we look at a combination of both the R-squared and MSE to make the best conclusion about the fit of the model.
# <ul>
#     <li><b>MSE</b>: The MSE of SLR is  3.16x10^7  while MLR has an MSE of 1.2 x10^7.  The MSE of MLR is much smaller.</li>
#     <li><b>R-squared</b>: In this case, we can also see that there is a big difference between the R-squared of the SLR and the R-squared of the MLR. The R-squared for the SLR (~0.497) is very small compared to the R-squared for the MLR (~0.809).</li>
# </ul>
# </p>
#
# This R-squared in combination with the MSE show that MLR seems like the better model fit in this case compared to SLR.

# %% [markdown]
# <h3>Simple Linear Model (SLR) vs. Polynomial Fit</h3>
#
# <ul>
#     <li><b>MSE</b>: We can see that Polynomial Fit brought down the MSE, since this MSE is smaller than the one from the SLR.</li>
#     <li><b>R-squared</b>: The R-squared for the Polynomial Fit is larger than the R-squared for the SLR, so the Polynomial Fit also brought up the R-squared quite a bit.</li>
# </ul>
# <p>Since the Polynomial Fit resulted in a lower MSE and a higher R-squared, we can conclude that this was a better fit model than the simple linear regression for predicting "price" with "highway-mpg" as a predictor variable.</p>

# %% [markdown]
# <h3>Multiple Linear Regression (MLR) vs. Polynomial Fit</h3>
#
# <ul>
#     <li><b>MSE</b>: The MSE for the MLR is smaller than the MSE for the Polynomial Fit.</li>
#     <li><b>R-squared</b>: The R-squared for the MLR is also much larger than for the Polynomial Fit.</li>
# </ul>

# %% [markdown]
# <h2>Conclusion</h2>
#
# <p>Comparing these three models, we conclude that <b>the MLR model is the best model</b> to be able to predict price from our dataset. This result makes sense since we have 27 variables in total and we know that more than one of those variables are potential predictors of the final car price.</p>
